# %% [markdown]
# <a href="https://colab.research.google.com/github/darshbs/R-Practice/blob/main/Segment2/Introduction_to_ggplot2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(tidyverse)
# Load the Motor Trend Car Road Tests (mtcars) dataset
# carData = data('mtcars') Loads the data set from the R
carData = read.csv('/content/mtcars.csv')

# %%
# Initiate the ggplot() function binding to the data frame
ggplot(data = carData)

# Create a plot object
carPlot = ggplot(data = carData)
# Out:
# plot without title

# %%
# Use the aes() function to specify the aesthetic mapping that is, which variables should be plotted
carPlot = ggplot(data = carData, aes(x = wt, y = disp))

# Use geom_ type functions to add geometric elements
carPlot = carPlot + geom_point()
carPlot
# Out:
# plot without title

# %%
# Add labels and title
carPlot = carPlot + labs(x = 'Weight (1000 lbs)', y = 'Displacement (cu. in)', title = 'Weight vs. Displacement')
carPlot
# Out:
# plot without title
